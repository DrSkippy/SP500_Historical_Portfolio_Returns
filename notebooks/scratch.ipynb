# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()
# %matplotlib inline

# %%
from returns.data import *
from returns.analysis import *

# %%
files = ! ls ../out_data/summary*
for i, f in enumerate(files):
    print(f"{i} : {f}")
# Out:
# 0 : ../out_data/summary_Buy_Hold_2023-12-13_1805.csv
# 1 : ../out_data/summary_Fractional_Kelly_0.1_180_2023-12-13_1808.csv
# 2 : ../out_data/summary_Fractional_Kelly_0.15_180_2023-12-13_1808.csv
# 3 : ../out_data/summary_Fractional_Kelly_0.15_90_2023-12-13_1808.csv
# 4 : ../out_data/summary_Fractional_Kelly_0.1_90_2023-12-13_1808.csv
# 5 : ../out_data/summary_Fractional_Kelly_0.2_180_2023-12-13_1808.csv
# 6 : ../out_data/summary_Fractional_Kelly_0.25_180_2023-12-13_1808.csv
# 7 : ../out_data/summary_Fractional_Kelly_0.25_90_2023-12-13_1808.csv
# 8 : ../out_data/summary_Fractional_Kelly_0.2_90_2023-12-13_1808.csv
# 9 : ../out_data/summary_Insurance_0.05_0.08_90_2023-12-13_1828.csv
# 10 : ../out_data/summary_Insurance_0.05_0.09_90_2023-12-14_1647.csv
# 11 : ../out_data/summary_Insurance_0.05_0.12_90_2023-12-14_1647.csv
# 12 : ../out_data/summary_Insurance_0.05_0.15_90_2023-12-13_1828.csv
# 13 : ../out_data/summary_Insurance_0.05_0.18_90_2023-12-14_1647.csv
# 14 : ../out_data/summary_Insurance_0.05_0.1_90_2023-12-13_1828.csv
# 15 : ../out_data/summary_Insurance_0.1_0.08_90_2023-12-13_1828.csv
# 16 : ../out_data/summary_Insurance_0.1_0.09_90_2023-12-14_1647.csv
# 17 : ../out_data/summary_Insurance_0.1_0.12_90_2023-12-14_1647.csv
# 18 : ../out_data/summary_Insurance_0.1_0.15_90_2023-12-13_1828.csv
# 19 : ../out_data/summary_Insurance_0.1_0.18_90_2023-12-14_1647.csv
# 20 : ../out_data/summary_Insurance_0.1_0.1_90_2023-12-13_1828.csv

# %%
d, h = read_summary_data(files[0])
plot_histograms(h)

# %%
show_metrics(d.iloc[10].to_list())
# Out:
# ### AGGREGATE RETURNS ### Buy_Hold ###
# Sample Size              = 6836
# Time span                =  11.0 years
# Mean Returns             = 130.23%
# Avg Yearly Return        = 6.94%
# Median Returns           = 109.86%
# Median Yearly Returns    = 6.97%
# StdDev of Returns        = 102.71%
# StdDev of Yearly Returns = 4.55%
# Losing start days        = 6.96%
# Mode of Returns          = -5.45%
# Mode of Yearly Returns   = 10.95%

# %%
drf = get_model_comparison_data(files)
#drf = drf.sort_values("model_name")
plot_period_comparison_data(drf)
