# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()
# %matplotlib inline

# %%
from returns.data import *
from returns.models import *
from returns.analysis import *

# %%
years = range(1,16)
files = !ls ../out_data

# %%
suffix = select_file(files)
d, h = get_model_run(suffix, years)
# Out:
# 0 - BettingMix_0.2_90_2023-10-03_1833.csv
# 1 - BettingMix_0.6_90_2023-10-03_1833.csv
# 2 - BettingMix_0.5_180_2023-10-02_2112.csv
# 3 - BettingMix_0.5_90_2023-10-02_2112.csv
# 4 - BettingMix_0.4_90_2023-10-02_2112.csv
# 5 - BettingMix_0.2_180_2023-10-03_1833.csv
# 6 - BettingMix_0.3_180_2023-10-02_2112.csv
# 7 - BettingMix_0.6_180_2023-10-03_1833.csv
# 8 - BettingMix_0.4_180_2023-10-02_2112.csv
# 9 - BettingMix_0.3_90_2023-10-02_2112.csv
# choose a number:  0
# Selected: BettingMix_0.2_90_2023-10-03_1833.csv
# Reading ../out_data/returns_1_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 8053 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_2_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7931 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_3_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7809 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_4_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7688 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_5_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7566 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_6_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7444 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_7_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7323 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_8_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7201 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_9_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 7079 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_10_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6958 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_11_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6836 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_12_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6714 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_13_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6593 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_14_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6471 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_15_BettingMix_0.2_90_2023-10-03_1833.csv
# Read 6349 rows
# Fields = ['date', 'return', 'time_span', 'model_name']

# %%
suffix1 = select_file(files)
d1, h1 = get_model_run(suffix1, years)
# Out:
# 0 - BettingMix_0.2_90_2023-10-03_1833.csv
# 1 - BettingMix_0.6_90_2023-10-03_1833.csv
# 2 - BettingMix_0.5_180_2023-10-02_2112.csv
# 3 - BettingMix_0.5_90_2023-10-02_2112.csv
# 4 - BettingMix_0.4_90_2023-10-02_2112.csv
# 5 - BettingMix_0.2_180_2023-10-03_1833.csv
# 6 - BettingMix_0.3_180_2023-10-02_2112.csv
# 7 - BettingMix_0.6_180_2023-10-03_1833.csv
# 8 - BettingMix_0.4_180_2023-10-02_2112.csv
# 9 - BettingMix_0.3_90_2023-10-02_2112.csv
# choose a number:  4
# Selected: BettingMix_0.4_90_2023-10-02_2112.csv
# Reading ../out_data/returns_1_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 8053 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_2_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7931 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_3_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7809 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_4_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7688 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_5_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7566 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_6_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7444 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_7_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7323 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_8_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7201 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_9_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 7079 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_10_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6958 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_11_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6836 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_12_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6714 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_13_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6593 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_14_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6471 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_15_BettingMix_0.4_90_2023-10-02_2112.csv
# Read 6349 rows
# Fields = ['date', 'return', 'time_span', 'model_name']

# %%
suffix2 = select_file(files)
d2, h2 = get_model_run(suffix2, years)
# Out:
# 0 - BettingMix_0.2_90_2023-10-03_1833.csv
# 1 - BettingMix_0.6_90_2023-10-03_1833.csv
# 2 - BettingMix_0.5_180_2023-10-02_2112.csv
# 3 - BettingMix_0.5_90_2023-10-02_2112.csv
# 4 - BettingMix_0.4_90_2023-10-02_2112.csv
# 5 - BettingMix_0.2_180_2023-10-03_1833.csv
# 6 - BettingMix_0.3_180_2023-10-02_2112.csv
# 7 - BettingMix_0.6_180_2023-10-03_1833.csv
# 8 - BettingMix_0.4_180_2023-10-02_2112.csv
# 9 - BettingMix_0.3_90_2023-10-02_2112.csv
# choose a number:  1
# Selected: BettingMix_0.6_90_2023-10-03_1833.csv
# Reading ../out_data/returns_1_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 8053 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_2_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7931 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_3_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7809 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_4_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7688 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_5_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7566 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_6_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7444 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_7_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7323 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_8_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7201 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_9_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 7079 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_10_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6958 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_11_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6836 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_12_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6714 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_13_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6593 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_14_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6471 rows
# Fields = ['date', 'return', 'time_span', 'model_name']
# Reading ../out_data/returns_15_BettingMix_0.6_90_2023-10-03_1833.csv
# Read 6349 rows
# Fields = ['date', 'return', 'time_span', 'model_name']

# %%
t = get_trend(d)
t1 = get_trend(d1)
t2 = get_trend(d2)
# Out:
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  1.00 years
# Mean = 6.97%
# Median = 8.15%
# Mode = 9.09%
# StDev = 12.66%
# Losing start days = 26.52%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  2.01 years
# Mean = 14.61%
# Median = 14.42%
# Mode = 13.28%
# StDev = 17.87%
# Losing start days = 16.47%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  3.00 years
# Mean = 22.45%
# Median = 23.09%
# Mode = 22.07%
# StDev = 22.77%
# Losing start days = 14.79%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  4.00 years
# Mean = 30.65%
# Median = 29.74%
# Mode = 24.29%
# StDev = 28.50%
# Losing start days = 15.92%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  5.00 years
# Mean = 39.56%
# Median = 40.23%
# Mode = 41.94%
# StDev = 35.11%
# Losing start days = 15.27%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  6.00 years
# Mean = 48.65%
# Median = 48.01%
# Mode = 61.78%
# StDev = 39.53%
# Losing start days = 9.01%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  7.00 years
# Mean = 58.38%
# Median = 51.94%
# Mode = 15.13%
# StDev = 44.42%
# Losing start days = 5.78%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  8.00 years
# Mean = 68.72%
# Median = 63.20%
# Mode = 27.14%
# StDev = 50.74%
# Losing start days = 4.15%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span =  9.01 years
# Mean = 80.14%
# Median = 71.02%
# Mode = 12.61%
# StDev = 58.18%
# Losing start days = 5.21%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 10.00 years
# Mean = 92.00%
# Median = 83.47%
# Mode = 60.18%
# StDev = 65.34%
# Losing start days = 5.04%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 11.00 years
# Mean = 104.57%
# Median = 92.95%
# Mode = 11.31%
# StDev = 73.47%
# Losing start days = 4.17%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 12.00 years
# Mean = 117.41%
# Median = 101.06%
# Mode = 25.21%
# StDev = 82.77%
# Losing start days = 0.74%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 13.00 years
# Mean = 130.84%
# Median = 107.94%
# Mode = 16.21%
# StDev = 91.95%
# Losing start days = 0.02%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 14.00 years
# Mean = 145.08%
# Median = 125.24%
# Mode = 22.29%
# StDev = 101.85%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.2_90 ###
# Time span = 15.00 years
# Mean = 160.13%
# Median = 135.55%
# Mode = 40.29%
# StDev = 114.29%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  1.00 years
# Mean = 5.69%
# Median = 6.66%
# Mode = 7.76%
# StDev = 9.44%
# Losing start days = 25.17%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  2.01 years
# Mean = 11.92%
# Median = 11.99%
# Mode = 11.04%
# StDev = 13.19%
# Losing start days = 14.42%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  3.00 years
# Mean = 18.26%
# Median = 18.95%
# Mode = 18.10%
# StDev = 16.53%
# Losing start days = 12.51%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  4.00 years
# Mean = 24.81%
# Median = 24.62%
# Mode = 30.26%
# StDev = 20.30%
# Losing start days = 13.03%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  5.00 years
# Mean = 31.79%
# Median = 32.83%
# Mode = 35.38%
# StDev = 24.65%
# Losing start days = 9.95%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  6.00 years
# Mean = 38.96%
# Median = 39.37%
# Mode = 46.27%
# StDev = 27.56%
# Losing start days = 4.51%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  7.00 years
# Mean = 46.55%
# Median = 43.07%
# Mode = 18.68%
# StDev = 30.70%
# Losing start days = 2.55%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  8.00 years
# Mean = 54.47%
# Median = 51.93%
# Mode = 27.09%
# StDev = 34.78%
# Losing start days = 2.17%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span =  9.01 years
# Mean = 63.06%
# Median = 58.11%
# Mode = 12.97%
# StDev = 39.62%
# Losing start days = 2.95%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 10.00 years
# Mean = 71.96%
# Median = 67.83%
# Mode = 50.53%
# StDev = 44.16%
# Losing start days = 3.46%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 11.00 years
# Mean = 81.29%
# Median = 75.51%
# Mode = 59.60%
# StDev = 49.17%
# Losing start days = 0.91%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 12.00 years
# Mean = 90.77%
# Median = 82.37%
# Mode = 28.34%
# StDev = 54.61%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 13.00 years
# Mean = 100.67%
# Median = 88.43%
# Mode = 83.53%
# StDev = 59.88%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 14.00 years
# Mean = 111.12%
# Median = 101.23%
# Mode = 31.62%
# StDev = 65.08%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.4_90 ###
# Time span = 15.00 years
# Mean = 121.97%
# Median = 109.58%
# Mode = 44.99%
# StDev = 71.55%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  1.00 years
# Mean = 4.42%
# Median = 5.12%
# Mode = 5.01%
# StDev = 6.26%
# Losing start days = 22.74%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  2.01 years
# Mean = 9.26%
# Median = 9.44%
# Mode = 8.74%
# StDev = 8.66%
# Losing start days = 12.05%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  3.00 years
# Mean = 14.14%
# Median = 14.76%
# Mode = 14.09%
# StDev = 10.67%
# Losing start days = 10.44%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  4.00 years
# Mean = 19.13%
# Median = 19.30%
# Mode = 22.20%
# StDev = 12.86%
# Losing start days = 6.67%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  5.00 years
# Mean = 24.37%
# Median = 25.36%
# Mode = 29.63%
# StDev = 15.39%
# Losing start days = 3.66%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  6.00 years
# Mean = 29.75%
# Median = 30.52%
# Mode = 35.05%
# StDev = 17.07%
# Losing start days = 0.89%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  7.00 years
# Mean = 35.38%
# Median = 33.93%
# Mode = 47.81%
# StDev = 18.85%
# Losing start days = 1.07%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  8.00 years
# Mean = 41.17%
# Median = 40.29%
# Mode = 60.59%
# StDev = 21.17%
# Losing start days = 0.97%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span =  9.01 years
# Mean = 47.33%
# Median = 45.11%
# Mode = 41.72%
# StDev = 23.97%
# Losing start days = 1.54%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 10.00 years
# Mean = 53.68%
# Median = 52.22%
# Mode = 76.78%
# StDev = 26.51%
# Losing start days = 0.66%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 11.00 years
# Mean = 60.29%
# Median = 58.20%
# Mode = 48.30%
# StDev = 29.19%
# Losing start days = 0.01%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 12.00 years
# Mean = 66.98%
# Median = 63.40%
# Mode = 29.22%
# StDev = 31.92%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 13.00 years
# Mean = 73.93%
# Median = 68.49%
# Mode = 65.41%
# StDev = 34.53%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 14.00 years
# Mean = 81.24%
# Median = 77.25%
# Mode = 31.64%
# StDev = 36.84%
# Losing start days = 0.00%
# ### AGGREGATE RETURNS ### BettingMix_0.6_90 ###
# Time span = 15.00 years
# Mean = 88.72%
# Median = 83.50%
# Mode = 44.32%
# StDev = 39.71%
# Losing start days = 0.00%

# %%
plot_trend(t, 3, "median returns", t1)
plot_trend(t, 5, "sdev returns", t1)

# %%
def plot_return_comps(frac_list = [], trend_list = [], year=10, index=3):
    a = [x[year-1] for x in trend_list]
    b = np.array(a).T[:index+1]
    b = b.astype(float)
    plt.plot(frac_list, b[index])
    plt.legend()
    plt.show()

plot_return_comps([.2, .4, .6],[t, t1, t2], year=10, index =3)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
